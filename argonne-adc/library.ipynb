# %%
import adc
import json
token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VybmFtZSI6ImdvbnphbG8ubWFydGluZXpAZG9tYW5kdG9tLmNvbSIsImV4cCI6MTYyODU5ODc3OCwib3JpZ0lhdCI6MTYyODU5ODQ3OH0.ME9fshLGae3qVJ-i6G4MY1ygoapzHpBXu8Wx6kRK6BM'
adc.authtoken(token)
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VybmFtZSI6ImdvbnphbG8ubWFydGluZXpAZG9tYW5kdG9tLmNvbSIsImV4cCI6MTYyODU5ODc3OCwib3JpZ0lhdCI6MTYyODU5ODQ3OH0.ME9fshLGae3qVJ-i6G4MY1ygoapzHpBXu8Wx6kRK6BM'

# %%
adc.showToken()
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VybmFtZSI6ImdvbnphbG8ubWFydGluZXpAZG9tYW5kdG9tLmNvbSIsImV4cCI6MTYyODU5ODc3OCwib3JpZ0lhdCI6MTYyODU5ODQ3OH0.ME9fshLGae3qVJ-i6G4MY1ygoapzHpBXu8Wx6kRK6BM'

# %%
me = adc.me()
print(me)
# Out:
# This is your response:
# {
#     "me": {
#         "email": "gonzalo.martinez@domandtom.com",
#         "id": "VXNlck5vZGU6MQ==",
#         "investigations": [
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6MQ==",
#                 "name": "Test Study Name",
#                 "samples": []
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mg==",
#                 "name": "Test Study Name",
#                 "samples": []
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mw==",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "test sample",
#                         "url": "/media/uploads/sample_1HDU9aA.json"
#                     }
# ...

# %%
all_users= adc.users()
print(all_users)
# Out:
# This is your response:
# {
#     "users": {
#         "edges": [
#             {
#                 "node": {
#                     "created": "2021-08-10T12:27:58.878038+00:00",
#                     "email": "gonzalo.martinez@domandtom.com",
#                     "id": "VXNlck5vZGU6MQ==",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MQ==",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mg==",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
# ...

# %%
id='VXNlck5vZGU6MQ=='
all_data_of_user = adc.user(id)
print(all_data_of_user)
# Out:
# This is your response:
# {
#     "users": {
#         "edges": [
#             {
#                 "node": {
#                     "created": "2021-08-10T12:27:58.878038+00:00",
#                     "email": "gonzalo.martinez@domandtom.com",
#                     "id": "VXNlck5vZGU6MQ==",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MQ==",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mg==",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
# ...

# %%
json_sample ="""{"name": "Test Study Name", "description": "Test Study Description", "keywords": ["test", "graphql", "demo", "argonne"]}"""
newStudy = adc.createStudy(json_sample)
print(newStudy)
# Out:
# This is your response:
# {
#     "createStudy": {
#         "study": {
#             "description": "Test Study Description",
#             "id": "U3R1ZHlOb2RlOjIy",
#             "investigations": [],
#             "isOwner": true,
#             "keywords": [
#                 "test",
#                 "graphql",
#                 "demo",
#                 "argonne"
#             ],
#             "name": "Test Study Name",
#             "user": {
#                 "id": "VXNlck5vZGU6MQ==",
#                 "username": "gonzalo.martinez@domandtom.com"
#             }
#         }
#     }
# }

# %%
studies = adc.studies()
print(studies)
# Out:
# This is your response:
# {
#     "studies": {
#         "edges": [
#             {
#                 "node": {
#                     "created": "2021-08-10T12:29:07.224440+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjE=",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MQ==",
#                             "name": "Test Study Name",
#                             "samples": []
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mg==",
#                             "name": "Test Study Name",
#                             "samples": []
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mw==",
#                             "name": "Test Study Name",
#                             "samples": [
# ...

# %%
study_id='U3R1ZHlOb2RlOjI2'
study_info = adc.study(study_id)
print(study_info)
# Out:
# This is your response:
# {
#     "study": null
# }

# %%
study_created_id=study_id
study_info = adc.study(study_created_id)
print(study_info)
# Out:
# This is your response:
# {
#     "study": null
# }

# %%
samples = adc.samples()
print(samples)
# Out:
# This is your response:
# {
#     "samples": {
#         "edges": [
#             {
#                 "node": {
#                     "created": "2021-08-10T12:33:15.298915+00:00",
#                     "id": "U2FtcGxlTm9kZTox",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-08-10T12:33:15.298928+00:00",
#                     "url": "/media/uploads/sample_pTt2FJX.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-10T12:41:26.031955+00:00",
# ...

# %%
sample_by_id = adc.sample("U2FtcGxlTm9kZToxMw==")
print(sample_by_id)
# Out:
# This is your response:
# {
#     "sample": {
#         "created": "2021-08-10T13:24:52.493576+00:00",
#         "id": "U2FtcGxlTm9kZToxMw==",
#         "isOwner": true,
#         "keywords": [
#             "test",
#             "python"
#         ],
#         "name": "test sample",
#         "updated": "2021-08-10T13:24:52.493594+00:00",
#         "url": "/media/uploads/sample_query_FvQTcqv.json",
#         "user": {
#             "email": "gonzalo.martinez@domandtom.com",
#             "id": "VXNlck5vZGU6MQ==",
#             "username": "gonzalo.martinez@domandtom.com"
#         }
#     }
# }

# %%
investigations= adc.investigations()
print(investigations)
# Out:
# This is your response:
# {
#     "investigations": {
#         "edges": [
#             {
#                 "node": {
#                     "created": "2021-08-10T12:29:35.795742+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MQ==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [],
#                     "study": {
#                         "description": "Test Study Description",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "test",
#                             "graphql",
#                             "demo",
#                             "argonne"
# ...

# %%
investigations_by_id= adc.investigation("SW52ZXN0aWdhdGlvbk5vZGU6MQ==")
# print(investigations_by_id)
result=json.loads(investigations_by_id)
print(result["investigation"])
# Out:
# This is your response:
# {'created': '2021-08-10T12:29:35.795742+00:00', 'description': 'Test Study Description', 'id': 'SW52ZXN0aWdhdGlvbk5vZGU6MQ==', 'isOwner': True, 'keywords': ['test', 'graphql', 'demo', 'argonne'], 'name': 'Test Study Name', 'samples': [], 'study': {'description': 'Test Study Description', 'id': 'U3R1ZHlOb2RlOjE=', 'keywords': ['test', 'graphql', 'demo', 'argonne'], 'name': 'Test Study Name'}, 'updated': '2021-08-10T12:29:35.795764+00:00', 'user': {'email': 'gonzalo.martinez@domandtom.com', 'id': 'VXNlck5vZGU6MQ==', 'username': 'gonzalo.martinez@domandtom.com'}}

# %%
investigation_sample = """{
    "name": "Test Study Name",
    "description": "Test Study Description",
    "keywords": ["test", "graphql", "demo", "argonne"],
    "sampleGlobalIds" : ["VXNlck5vZGU6Mg=="],
    "studyGlobalId": "U3R1ZHlOb2RlOjE="
}"""
create_investigation = adc.createInvestigation(investigation_sample)
print(create_investigation)
# Out:
# This is your response:
# {
#     "createInvestigation": {
#         "investigation": {
#             "description": "Test Study Description",
#             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MjI=",
#             "isOwner": true,
#             "keywords": [
#                 "test",
#                 "graphql",
#                 "demo",
#                 "argonne"
#             ],
#             "name": "Test Study Name",
#             "samples": [
#                 {
#                     "id": "U2FtcGxlTm9kZToy"
#                 }
#             ],
#             "study": {
#                 "id": "U3R1ZHlOb2RlOjE=",
#                 "name": "Test Study Name"
#             },
#             "user": {
#                 "id": "VXNlck5vZGU6MQ==",
#                 "username": "gonzalo.martinez@domandtom.com"
#             }
#         }
#     }
# }

# %%
opcion3=adc.createsampleWithFile("sample.json")
print(opcion3)
# Out:
# This is your response:
# {
#     "data": {
#         "createSample": {
#             "sample": {
#                 "id": "U2FtcGxlTm9kZToxNQ==",
#                 "keywords": [
#                     "test",
#                     "python"
#                 ],
#                 "name": "test sample",
#                 "url": "/media/uploads/samplejson_j2Crsim"
#             }
#         }
#     }
# }

# %%
my_sample="""{"name": "Test Study Name", "description": "Test Study Description", "keywords": ["test", "graphql", "demo", "argonne"]}"""
withStr=adc.cSampleWithStr(my_sample)
print(withStr)
# Out:
# This is your response:
# {'data': {'createSample': {'sample': {'id': 'U2FtcGxlTm9kZToxOA==', 'name': 'test sample', 'keywords': ['test', 'python'], 'url': '/media/uploads/sample_query_ed5ql0v.json'}}}}

# %%
my_sample="""{"name": "Test Study Name", "description": "Test Study Description", "keywords": ["test", "graphql", "demo", "argonne"]}"""
withStr=adc.cSampleWithStr(my_sample,"example.json")
print(withStr)
# Out:
# This is your response:
# {'data': {'createSample': {'sample': {'id': 'U2FtcGxlTm9kZToxOQ==', 'name': 'test sample', 'keywords': ['test', 'python'], 'url': '/media/uploads/example.json'}}}}

# %%
opcion2=adc.createsample()
print(opcion2)
# Out:
# enter file
#  sample.json
# This is your response:
# {
#     "data": {
#         "createSample": {
#             "sample": {
#                 "id": "U2FtcGxlTm9kZToxNw==",
#                 "keywords": [
#                     "test",
#                     "python"
#                 ],
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_K3QoaOh.json"
#             }
#         }
#     }
# }
