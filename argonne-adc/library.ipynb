# %%
import adc
token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VybmFtZSI6ImdvbnphbG8ubWFydGluZXpAZG9tYW5kdG9tLmNvbSIsImV4cCI6MTYyODE5MzA2Nywib3JpZ0lhdCI6MTYyODE5Mjc2N30.sBURTmqSsPmHJcK5Sz4tcpymrvhiCzHUld08Mas9WEo'
adc.authtoken(token)
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VybmFtZSI6ImdvbnphbG8ubWFydGluZXpAZG9tYW5kdG9tLmNvbSIsImV4cCI6MTYyODE5MzA2Nywib3JpZ0lhdCI6MTYyODE5Mjc2N30.sBURTmqSsPmHJcK5Sz4tcpymrvhiCzHUld08Mas9WEo'

# %%
adc.showToken()
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VybmFtZSI6ImdvbnphbG8ubWFydGluZXpAZG9tYW5kdG9tLmNvbSIsImV4cCI6MTYyODE5MzA2Nywib3JpZ0lhdCI6MTYyODE5Mjc2N30.sBURTmqSsPmHJcK5Sz4tcpymrvhiCzHUld08Mas9WEo'

# %%
me = adc.me()
print(me)
# Out:
# This is your response:
# {
#     "me": {
#         "email": "gonzalo.martinez@domandtom.com",
#         "id": "VXNlck5vZGU6MQ==",
#         "investigations": [
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6Ng==",
#                 "name": "Test Study Name",
#                 "samples": []
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6Nw==",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "Test Sample 2",
#                         "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                     }
#                 ]
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6OA==",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "Test Sample 2",
#                         "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                     }
#                 ]
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6OQ==",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "Test Sample 2",
#                         "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                     }
#                 ]
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTA=",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "Test Sample 2",
#                         "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                     }
#                 ]
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTE=",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "Test Sample 2",
#                         "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                     }
#                 ]
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTI=",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "Test Sample 2",
#                         "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                     }
#                 ]
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTM=",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "Test Sample 2",
#                         "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                     }
#                 ]
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTQ=",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "Test Sample 2",
#                         "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                     }
#                 ]
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTU=",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "Test Sample 2",
#                         "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                     }
#                 ]
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTY=",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "Test Sample 2",
#                         "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                     }
#                 ]
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTc=",
#                 "name": "Test Study Name",
#                 "samples": [
#                     {
#                         "name": "Test Sample 2",
#                         "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                     }
#                 ]
#             }
#         ],
#         "samples": [
#             {
#                 "id": "U2FtcGxlTm9kZTo2",
#                 "name": "test sample",
#                 "url": "/media/uploads/avatarwithoutBack.png"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZTo3",
#                 "name": "test sample",
#                 "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZTo4",
#                 "name": "test sample",
#                 "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_eBEBdRS.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZTo5",
#                 "name": "test sample",
#                 "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_DfuBZoK.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToxMA==",
#                 "name": "test sample",
#                 "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_4ie55IO.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToxMQ==",
#                 "name": "test sample",
#                 "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_MpPZ8tQ.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToxMg==",
#                 "name": "test sample",
#                 "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_JePqcPm.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToxMw==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToxNA==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_rqGOK5s.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToxNQ==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_F46sOrN.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToxNg==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_RH1jsuy.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToxNw==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_13F6B1n.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToxOA==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_9VJd4Hi.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToxOQ==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_yzJME1l.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToyMA==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_QcFNesa.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToyMQ==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_N8Vjwyy.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToyMg==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_hT4PkMS.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToyMw==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_ky6hdaH.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToyNA==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_J5pUWG2.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToyNQ==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_8Jw1tJH.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToyNg==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_NGQAV2x.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToyNw==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_26o70dn.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToyOA==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_UWavhvA.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZToyOQ==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_Eb7D9hi.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZTozMA==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_fkHQcG6.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZTozMQ==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_q81onUd.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZTozMg==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_OvPrDya.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZTozMw==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_tfJGat5.json"
#             },
#             {
#                 "id": "U2FtcGxlTm9kZTozNA==",
#                 "name": "test sample",
#                 "url": "/media/uploads/sample_u9Eih58.json"
#             }
#         ],
#         "studies": [
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjY=",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjc=",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjg=",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjk=",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjEw",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjEx",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjEy",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjEz",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjE0",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjE1",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjE2",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjE3",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjE4",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjE5",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjIw",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjIx",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjIy",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjIz",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjI0",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjI1",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjI2",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjI3",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjI4",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjI5",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjMw",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjMx",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjMy",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjMz",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjM0",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjM1",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjM2",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjM3",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjM4",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjM5",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjQw",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjQx",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjQy",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjQz",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjQ0",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjQ1",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjQ2",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjQ3",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjQ4",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjQ5",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjUw",
#                 "name": "Test Study Name"
#             },
#             {
#                 "description": "Test Study Description",
#                 "id": "U3R1ZHlOb2RlOjUx",
#                 "name": "Test Study Name"
#             }
#         ],
#         "username": "gonzalo.martinez@domandtom.com"
#     }
# }

# %%
all_users= adc.users()
print(all_users)

# %%
id='VXNlck5vZGU6MQ=='
all_data_of_user = adc.user(id)
print(all_data_of_user)
# Out:
# This is your response:
# {
#     "users": {
#         "edges": [
#             {
#                 "node": {
#                     "created": "2021-07-22T14:22:10.308545+00:00",
#                     "email": "gonzalo.martinez@domandtom.com",
#                     "id": "VXNlck5vZGU6MQ==",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Ng==",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Nw==",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6OA==",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6OQ==",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTA=",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTE=",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTI=",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTM=",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTQ=",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTU=",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTY=",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTc=",
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         }
#                     ],
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZTo2",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/avatarwithoutBack.png"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZTo3",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZTo4",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_eBEBdRS.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZTo5",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_DfuBZoK.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToxMA==",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_4ie55IO.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToxMQ==",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_MpPZ8tQ.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToxMg==",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_JePqcPm.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToxMw==",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToxNA==",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_rqGOK5s.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToxNQ==",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_F46sOrN.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToxNg==",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_RH1jsuy.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToxNw==",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_13F6B1n.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToxOA==",
#                             "keywords": [
#                                 "test",
#                                 "python"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_9VJd4Hi.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToxOQ==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_yzJME1l.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToyMA==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_QcFNesa.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToyMQ==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_N8Vjwyy.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToyMg==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_hT4PkMS.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToyMw==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_ky6hdaH.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToyNA==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_J5pUWG2.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToyNQ==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_8Jw1tJH.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToyNg==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_NGQAV2x.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToyNw==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_26o70dn.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToyOA==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_UWavhvA.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZToyOQ==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_Eb7D9hi.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZTozMA==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_fkHQcG6.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZTozMQ==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_q81onUd.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZTozMg==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_OvPrDya.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZTozMw==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_tfJGat5.json"
#                         },
#                         {
#                             "id": "U2FtcGxlTm9kZTozNA==",
#                             "keywords": [
#                                 "python",
#                                 "test"
#                             ],
#                             "name": "test sample",
#                             "url": "/media/uploads/sample_u9Eih58.json"
#                         }
#                     ],
#                     "studies": [
#                         {
#                             "id": "U3R1ZHlOb2RlOjY=",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjc=",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjg=",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjk=",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjEw",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonneYeah"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjEx",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjEy",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjEz",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonneYeah"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjE0",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonneYeah"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjE1",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjE2",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonneYeah"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjE3",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjE4",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjE5",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjIw",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjIx",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjIy",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjIz",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjI0",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjI1",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjI2",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjI3",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjI4",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjI5",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjMw",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjMx",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjMy",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjMz",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjM0",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjM1",
#                             "investigations": [],
#                             "keywords": [
#                                 "test",
#                                 "graphql",
#                                 "demo",
#                                 "argonne"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjM2",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjM3",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjM4",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjM5",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjQw",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjQx",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjQy",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjQz",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjQ0",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjQ1",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjQ2",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjQ3",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjQ4",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjQ5",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjUw",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         },
#                         {
#                             "id": "U3R1ZHlOb2RlOjUx",
#                             "investigations": [],
#                             "keywords": [
#                                 "demo",
#                                 "argonne",
#                                 "test",
#                                 "graphql"
#                             ],
#                             "name": "Test Study Name"
#                         }
#                     ],
#                     "updated": "2021-07-22T14:22:10.308568+00:00",
#                     "username": "gonzalo.martinez@domandtom.com"
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.826227+00:00",
#                     "email": "mayodeanna@williamson.com",
#                     "id": "VXNlck5vZGU6Mg==",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MQ==",
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Investigation 0"
#                         }
#                     ],
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZTox",
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Sample 1",
#                             "url": "/media/uploads/simplified_sample.json"
#                         }
#                     ],
#                     "studies": [
#                         {
#                             "id": "U3R1ZHlOb2RlOjE=",
#                             "investigations": [
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MQ==",
#                                     "keywords": [
#                                         "Keyword 0",
#                                         "Keyword 1",
#                                         "Keyword 2",
#                                         "Keyword 3",
#                                         "Keyword 4"
#                                     ],
#                                     "name": "Test Investigation 0"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6Ng==",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6Nw==",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6OA==",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6OQ==",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTA=",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTE=",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTI=",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTM=",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTQ=",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTU=",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTY=",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 },
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTc=",
#                                     "keywords": [
#                                         "test",
#                                         "graphql",
#                                         "demo",
#                                         "argonne"
#                                     ],
#                                     "name": "Test Study Name"
#                                 }
#                             ],
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Study 0"
#                         }
#                     ],
#                     "updated": "2021-07-22T14:24:24.826238+00:00",
#                     "username": "sherry38"
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.842762+00:00",
#                     "email": "carrillopatrick@hotmail.com",
#                     "id": "VXNlck5vZGU6Mw==",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mg==",
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Investigation 1"
#                         }
#                     ],
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "studies": [
#                         {
#                             "id": "U3R1ZHlOb2RlOjI=",
#                             "investigations": [
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mg==",
#                                     "keywords": [
#                                         "Keyword 0",
#                                         "Keyword 1",
#                                         "Keyword 2",
#                                         "Keyword 3",
#                                         "Keyword 4"
#                                     ],
#                                     "name": "Test Investigation 1"
#                                 }
#                             ],
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Study 1"
#                         }
#                     ],
#                     "updated": "2021-07-22T14:24:24.842770+00:00",
#                     "username": "combsashlee"
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.850336+00:00",
#                     "email": "peggyspears@yahoo.com",
#                     "id": "VXNlck5vZGU6NA==",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mw==",
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Investigation 2"
#                         }
#                     ],
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToz",
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Sample 3",
#                             "url": "/media/uploads/simplified_sample_UYlPLPB.json"
#                         }
#                     ],
#                     "studies": [
#                         {
#                             "id": "U3R1ZHlOb2RlOjM=",
#                             "investigations": [
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mw==",
#                                     "keywords": [
#                                         "Keyword 0",
#                                         "Keyword 1",
#                                         "Keyword 2",
#                                         "Keyword 3",
#                                         "Keyword 4"
#                                     ],
#                                     "name": "Test Investigation 2"
#                                 }
#                             ],
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Study 2"
#                         }
#                     ],
#                     "updated": "2021-07-22T14:24:24.850343+00:00",
#                     "username": "mmckay"
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.856984+00:00",
#                     "email": "peterscristina@hotmail.com",
#                     "id": "VXNlck5vZGU6NQ==",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6NA==",
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Investigation 3"
#                         }
#                     ],
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZTo0",
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Sample 4",
#                             "url": "/media/uploads/simplified_sample_qANM8An.json"
#                         }
#                     ],
#                     "studies": [
#                         {
#                             "id": "U3R1ZHlOb2RlOjQ=",
#                             "investigations": [
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6NA==",
#                                     "keywords": [
#                                         "Keyword 0",
#                                         "Keyword 1",
#                                         "Keyword 2",
#                                         "Keyword 3",
#                                         "Keyword 4"
#                                     ],
#                                     "name": "Test Investigation 3"
#                                 }
#                             ],
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Study 3"
#                         }
#                     ],
#                     "updated": "2021-07-22T14:24:24.856990+00:00",
#                     "username": "rfuller"
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.861936+00:00",
#                     "email": "icabrera@gmail.com",
#                     "id": "VXNlck5vZGU6Ng==",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6NQ==",
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Investigation 4"
#                         }
#                     ],
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZTo1",
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Sample 5",
#                             "url": "/media/uploads/simplified_sample_FsuBL5A.json"
#                         }
#                     ],
#                     "studies": [
#                         {
#                             "id": "U3R1ZHlOb2RlOjU=",
#                             "investigations": [
#                                 {
#                                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6NQ==",
#                                     "keywords": [
#                                         "Keyword 0",
#                                         "Keyword 1",
#                                         "Keyword 2",
#                                         "Keyword 3",
#                                         "Keyword 4"
#                                     ],
#                                     "name": "Test Investigation 4"
#                                 }
#                             ],
#                             "keywords": [
#                                 "Keyword 0",
#                                 "Keyword 1",
#                                 "Keyword 2",
#                                 "Keyword 3",
#                                 "Keyword 4"
#                             ],
#                             "name": "Test Study 4"
#                         }
#                     ],
#                     "updated": "2021-07-22T14:24:24.861941+00:00",
#                     "username": "kentsanchez"
#                 }
#             }
#         ]
#     }
# }

# %%
json_sample ="""{"name": "Test Study Name", "description": "Test Study Description", "keywords": ["test", "graphql", "demo", "argonne"]}"""
newStudy = adc.createStudy(json_sample)
print(newStudy)
# Out:
# This is your response:
# {
#     "createStudy": {
#         "study": {
#             "description": "Test Study Description",
#             "id": "U3R1ZHlOb2RlOjUy",
#             "investigations": [],
#             "isOwner": true,
#             "keywords": [
#                 "demo",
#                 "argonne",
#                 "test",
#                 "graphql"
#             ],
#             "name": "Test Study Name",
#             "user": {
#                 "id": "VXNlck5vZGU6MQ==",
#                 "username": "gonzalo.martinez@domandtom.com"
#             }
#         }
#     }
# }

# %%
studies = adc.studies()
print(studies)
# Out:
# This is your response:
# {
#     "studies": {
#         "edges": [
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.828652+00:00",
#                     "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                     "id": "U3R1ZHlOb2RlOjE=",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MQ==",
#                             "name": "Test Investigation 0",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZTox",
#                                     "name": "Test Sample 1",
#                                     "url": "/media/uploads/simplified_sample.json"
#                                 }
#                             ]
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Ng==",
#                             "name": "Test Study Name",
#                             "samples": []
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Nw==",
#                             "name": "Test Study Name",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6OA==",
#                             "name": "Test Study Name",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6OQ==",
#                             "name": "Test Study Name",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTA=",
#                             "name": "Test Study Name",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTE=",
#                             "name": "Test Study Name",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTI=",
#                             "name": "Test Study Name",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTM=",
#                             "name": "Test Study Name",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTQ=",
#                             "name": "Test Study Name",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTU=",
#                             "name": "Test Study Name",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTY=",
#                             "name": "Test Study Name",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         },
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTc=",
#                             "name": "Test Study Name",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         }
#                     ],
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Study 0",
#                     "updated": "2021-07-22T14:24:24.828665+00:00",
#                     "user": {
#                         "email": "mayodeanna@williamson.com",
#                         "id": "VXNlck5vZGU6Mg==",
#                         "username": "sherry38"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.844341+00:00",
#                     "description": "Drop defense star hospital raise recently. Policy possible degree often.\nWell us game Democrat.\nDetermine security music deal ball. Notice traditional allow protect country care glass.",
#                     "id": "U3R1ZHlOb2RlOjI=",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mg==",
#                             "name": "Test Investigation 1",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToy",
#                                     "name": "Test Sample 2",
#                                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                                 }
#                             ]
#                         }
#                     ],
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Study 1",
#                     "updated": "2021-07-22T14:24:24.844351+00:00",
#                     "user": {
#                         "email": "carrillopatrick@hotmail.com",
#                         "id": "VXNlck5vZGU6Mw==",
#                         "username": "combsashlee"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.851772+00:00",
#                     "description": "Threat collection management skill general. Security statement range.\nEdge security water choice determine save fire simply. Campaign drug pass subject. Yes expect campaign his end this.",
#                     "id": "U3R1ZHlOb2RlOjM=",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mw==",
#                             "name": "Test Investigation 2",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZToz",
#                                     "name": "Test Sample 3",
#                                     "url": "/media/uploads/simplified_sample_UYlPLPB.json"
#                                 }
#                             ]
#                         }
#                     ],
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Study 2",
#                     "updated": "2021-07-22T14:24:24.851779+00:00",
#                     "user": {
#                         "email": "peggyspears@yahoo.com",
#                         "id": "VXNlck5vZGU6NA==",
#                         "username": "mmckay"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.857936+00:00",
#                     "description": "Wind purpose in product himself collection say. Language somebody fill future. Impact tree model.",
#                     "id": "U3R1ZHlOb2RlOjQ=",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6NA==",
#                             "name": "Test Investigation 3",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZTo0",
#                                     "name": "Test Sample 4",
#                                     "url": "/media/uploads/simplified_sample_qANM8An.json"
#                                 }
#                             ]
#                         }
#                     ],
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Study 3",
#                     "updated": "2021-07-22T14:24:24.857943+00:00",
#                     "user": {
#                         "email": "peterscristina@hotmail.com",
#                         "id": "VXNlck5vZGU6NQ==",
#                         "username": "rfuller"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.862793+00:00",
#                     "description": "Plant window education inside test. Spring know figure certainly want development brother.\nCouple throw fish suddenly. Individual kitchen factor develop network institution.",
#                     "id": "U3R1ZHlOb2RlOjU=",
#                     "investigations": [
#                         {
#                             "id": "SW52ZXN0aWdhdGlvbk5vZGU6NQ==",
#                             "name": "Test Investigation 4",
#                             "samples": [
#                                 {
#                                     "id": "U2FtcGxlTm9kZTo1",
#                                     "name": "Test Sample 5",
#                                     "url": "/media/uploads/simplified_sample_FsuBL5A.json"
#                                 }
#                             ]
#                         }
#                     ],
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Study 4",
#                     "updated": "2021-07-22T14:24:24.862799+00:00",
#                     "user": {
#                         "email": "icabrera@gmail.com",
#                         "id": "VXNlck5vZGU6Ng==",
#                         "username": "kentsanchez"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T19:46:07.747605+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjY=",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-07-22T19:46:07.747658+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T20:29:26.498753+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjc=",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-07-22T20:29:26.498817+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T17:41:26.773005+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjg=",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T17:41:26.773030+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T17:42:22.356956+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjk=",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T17:42:22.356980+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T17:44:12.209170+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjEw",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonneYeah"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T17:44:12.209199+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T17:46:50.654746+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjEx",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T17:46:50.654775+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T17:47:15.435583+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjEy",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T17:47:15.435594+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T17:47:24.124252+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjEz",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonneYeah"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T17:47:24.124284+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T17:57:56.354054+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjE0",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonneYeah"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T17:57:56.354080+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:16:59.480108+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjE1",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T18:16:59.480145+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:28:05.037729+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjE2",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonneYeah"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T18:28:05.037754+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:28:25.151527+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjE3",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T18:28:25.151538+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:31:54.839107+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjE4",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T18:31:54.839137+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:41:43.441169+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjE5",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T18:41:43.441209+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:43:25.822746+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjIw",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T18:43:25.822776+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:50:40.445835+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjIx",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T18:50:40.445873+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:57:40.798573+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjIy",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T18:57:40.798600+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:58:57.435674+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjIz",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T18:58:57.435683+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:59:28.926324+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjI0",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T18:59:28.926344+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T19:21:22.317925+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjI1",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T19:21:22.317934+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T19:26:58.978347+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjI2",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T19:26:58.978356+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T19:41:20.048587+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjI3",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T19:41:20.048596+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T20:24:48.060953+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjI4",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T20:24:48.060970+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T20:29:32.392408+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjI5",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T20:29:32.392419+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T20:36:56.525233+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjMw",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T20:36:56.525243+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T20:59:28.316042+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjMx",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T20:59:28.316052+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T21:00:47.975854+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjMy",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T21:00:47.975865+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T21:01:39.262111+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjMz",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T21:01:39.262121+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T21:15:15.567262+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjM0",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T21:15:15.567274+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T21:17:10.494655+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjM1",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T21:17:10.494665+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T21:21:53.499148+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjM2",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T21:21:53.499158+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T21:23:11.411468+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjM3",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T21:23:11.411478+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T21:23:34.675617+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjM4",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T21:23:34.675629+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T21:25:42.187519+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjM5",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T21:25:42.187529+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T21:29:01.546974+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjQw",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T21:29:01.546984+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T21:30:54.618309+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjQx",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T21:30:54.618318+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T22:06:49.190446+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjQy",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T22:06:49.190464+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T22:26:21.483779+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjQz",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T22:26:21.483790+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T22:30:16.800694+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjQ0",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T22:30:16.800705+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T22:36:07.167733+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjQ1",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T22:36:07.167747+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T22:36:20.091104+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjQ2",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T22:36:20.091114+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T22:40:05.212069+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjQ3",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-05T22:40:05.212083+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-06T10:10:13.417035+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjQ4",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-06T10:10:13.417047+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-06T10:33:26.134463+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjQ5",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-06T10:33:26.134508+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-06T11:08:13.764865+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjUw",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-06T11:08:13.764889+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-06T11:11:22.801697+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjUx",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-06T11:11:22.801706+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-06T11:13:23.725763+00:00",
#                     "description": "Test Study Description",
#                     "id": "U3R1ZHlOb2RlOjUy",
#                     "investigations": [],
#                     "isOwner": true,
#                     "keywords": [
#                         "demo",
#                         "argonne",
#                         "test",
#                         "graphql"
#                     ],
#                     "name": "Test Study Name",
#                     "updated": "2021-08-06T11:13:23.725773+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             }
#         ]
#     }
# }

# %%
study_id='U3R1ZHlOb2RlOjI2'
study_info = adc.study(study_id)
print(study_info)
# Out:
# This is your response:
# {
#     "study": {
#         "created": "2021-08-05T19:26:58.978347+00:00",
#         "description": "Test Study Description",
#         "id": "U3R1ZHlOb2RlOjI2",
#         "investigations": [],
#         "isOwner": true,
#         "keywords": [
#             "test",
#             "graphql",
#             "demo",
#             "argonne"
#         ],
#         "name": "Test Study Name",
#         "updated": "2021-08-05T19:26:58.978356+00:00",
#         "user": {
#             "email": "gonzalo.martinez@domandtom.com",
#             "id": "VXNlck5vZGU6MQ==",
#             "username": "gonzalo.martinez@domandtom.com"
#         }
#     }
# }

# %%
study_created_id=study_id
study_info = adc.study(study_created_id)
print(study_info)
# Out:
# This is your response:
# {
#     "study": {
#         "created": "2021-08-05T19:26:58.978347+00:00",
#         "description": "Test Study Description",
#         "id": "U3R1ZHlOb2RlOjI2",
#         "investigations": [],
#         "isOwner": true,
#         "keywords": [
#             "test",
#             "graphql",
#             "demo",
#             "argonne"
#         ],
#         "name": "Test Study Name",
#         "updated": "2021-08-05T19:26:58.978356+00:00",
#         "user": {
#             "email": "gonzalo.martinez@domandtom.com",
#             "id": "VXNlck5vZGU6MQ==",
#             "username": "gonzalo.martinez@domandtom.com"
#         }
#     }
# }

# %%
samples = adc.samples()
print(samples)
# Out:
# This is your response:
# {
#     "samples": {
#         "edges": [
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.872097+00:00",
#                     "id": "U2FtcGxlTm9kZTox",
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Sample 1",
#                     "updated": "2021-07-22T14:24:24.880941+00:00",
#                     "url": "/media/uploads/simplified_sample.json",
#                     "user": {
#                         "email": "mayodeanna@williamson.com",
#                         "id": "VXNlck5vZGU6Mg==",
#                         "username": "sherry38"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.896277+00:00",
#                     "id": "U2FtcGxlTm9kZTo1",
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Sample 5",
#                     "updated": "2021-07-22T14:24:24.897841+00:00",
#                     "url": "/media/uploads/simplified_sample_FsuBL5A.json",
#                     "user": {
#                         "email": "icabrera@gmail.com",
#                         "id": "VXNlck5vZGU6Ng==",
#                         "username": "kentsanchez"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.889214+00:00",
#                     "id": "U2FtcGxlTm9kZToz",
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Sample 3",
#                     "updated": "2021-07-22T14:24:24.890941+00:00",
#                     "url": "/media/uploads/simplified_sample_UYlPLPB.json",
#                     "user": {
#                         "email": "peggyspears@yahoo.com",
#                         "id": "VXNlck5vZGU6NA==",
#                         "username": "mmckay"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.892823+00:00",
#                     "id": "U2FtcGxlTm9kZTo0",
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Sample 4",
#                     "updated": "2021-07-22T14:24:24.894540+00:00",
#                     "url": "/media/uploads/simplified_sample_qANM8An.json",
#                     "user": {
#                         "email": "peterscristina@hotmail.com",
#                         "id": "VXNlck5vZGU6NQ==",
#                         "username": "rfuller"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.885334+00:00",
#                     "id": "U2FtcGxlTm9kZToy",
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Sample 2",
#                     "updated": "2021-07-22T14:24:24.887182+00:00",
#                     "url": "/media/uploads/simplified_sample_8JF3Ryx.json",
#                     "user": {
#                         "email": "carrillopatrick@hotmail.com",
#                         "id": "VXNlck5vZGU6Mw==",
#                         "username": "combsashlee"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T20:55:55.201490+00:00",
#                     "id": "U2FtcGxlTm9kZTo2",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T20:55:55.201503+00:00",
#                     "url": "/media/uploads/avatarwithoutBack.png",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T21:51:44.581582+00:00",
#                     "id": "U2FtcGxlTm9kZTo3",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T21:51:44.581591+00:00",
#                     "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T22:04:51.126925+00:00",
#                     "id": "U2FtcGxlTm9kZTo4",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T22:04:51.126937+00:00",
#                     "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_eBEBdRS.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T22:07:16.805216+00:00",
#                     "id": "U2FtcGxlTm9kZTo5",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T22:07:16.805232+00:00",
#                     "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_DfuBZoK.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T22:50:40.463834+00:00",
#                     "id": "U2FtcGxlTm9kZToxMA==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T22:50:40.463844+00:00",
#                     "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_4ie55IO.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T22:52:59.126408+00:00",
#                     "id": "U2FtcGxlTm9kZToxMQ==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T22:52:59.126417+00:00",
#                     "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_MpPZ8tQ.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T22:54:30.805532+00:00",
#                     "id": "U2FtcGxlTm9kZToxMg==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T22:54:30.805550+00:00",
#                     "url": "/media/uploads/Argonne_Discovery_Cloud.postman_collection_JePqcPm.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T22:55:22.860050+00:00",
#                     "id": "U2FtcGxlTm9kZToxMw==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T22:55:22.860073+00:00",
#                     "url": "/media/uploads/sample.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:09:53.327814+00:00",
#                     "id": "U2FtcGxlTm9kZToxNA==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:09:53.327830+00:00",
#                     "url": "/media/uploads/sample_rqGOK5s.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:10:55.118967+00:00",
#                     "id": "U2FtcGxlTm9kZToxNQ==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:10:55.118987+00:00",
#                     "url": "/media/uploads/sample_F46sOrN.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:12:42.801119+00:00",
#                     "id": "U2FtcGxlTm9kZToxNg==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:12:42.801139+00:00",
#                     "url": "/media/uploads/sample_RH1jsuy.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:14:15.371420+00:00",
#                     "id": "U2FtcGxlTm9kZToxNw==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:14:15.371430+00:00",
#                     "url": "/media/uploads/sample_13F6B1n.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:15:11.106085+00:00",
#                     "id": "U2FtcGxlTm9kZToxOA==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "python"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:15:11.106094+00:00",
#                     "url": "/media/uploads/sample_9VJd4Hi.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:16:14.863571+00:00",
#                     "id": "U2FtcGxlTm9kZToxOQ==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:16:14.863581+00:00",
#                     "url": "/media/uploads/sample_yzJME1l.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:18:18.484718+00:00",
#                     "id": "U2FtcGxlTm9kZToyMA==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:18:18.484807+00:00",
#                     "url": "/media/uploads/sample_QcFNesa.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:25:44.188626+00:00",
#                     "id": "U2FtcGxlTm9kZToyMQ==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:25:44.188637+00:00",
#                     "url": "/media/uploads/sample_N8Vjwyy.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:26:45.278868+00:00",
#                     "id": "U2FtcGxlTm9kZToyMg==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:26:45.278876+00:00",
#                     "url": "/media/uploads/sample_hT4PkMS.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:27:39.526358+00:00",
#                     "id": "U2FtcGxlTm9kZToyMw==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:27:39.526370+00:00",
#                     "url": "/media/uploads/sample_ky6hdaH.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:32:32.834682+00:00",
#                     "id": "U2FtcGxlTm9kZToyNA==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:32:32.834704+00:00",
#                     "url": "/media/uploads/sample_J5pUWG2.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:33:46.329617+00:00",
#                     "id": "U2FtcGxlTm9kZToyNQ==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:33:46.329637+00:00",
#                     "url": "/media/uploads/sample_8Jw1tJH.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:34:23.212980+00:00",
#                     "id": "U2FtcGxlTm9kZToyNg==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:34:23.213000+00:00",
#                     "url": "/media/uploads/sample_NGQAV2x.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:36:52.318223+00:00",
#                     "id": "U2FtcGxlTm9kZToyNw==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:36:52.318248+00:00",
#                     "url": "/media/uploads/sample_26o70dn.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:42:53.174734+00:00",
#                     "id": "U2FtcGxlTm9kZToyOA==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:42:53.174755+00:00",
#                     "url": "/media/uploads/sample_UWavhvA.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T23:44:15.895575+00:00",
#                     "id": "U2FtcGxlTm9kZToyOQ==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-07-22T23:44:15.895598+00:00",
#                     "url": "/media/uploads/sample_Eb7D9hi.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T20:53:31.763025+00:00",
#                     "id": "U2FtcGxlTm9kZTozMA==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-08-05T20:53:31.763050+00:00",
#                     "url": "/media/uploads/sample_fkHQcG6.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T20:56:41.116617+00:00",
#                     "id": "U2FtcGxlTm9kZTozMQ==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-08-05T20:56:41.116637+00:00",
#                     "url": "/media/uploads/sample_q81onUd.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T21:23:50.888797+00:00",
#                     "id": "U2FtcGxlTm9kZTozMg==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-08-05T21:23:50.888813+00:00",
#                     "url": "/media/uploads/sample_OvPrDya.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T22:37:42.356238+00:00",
#                     "id": "U2FtcGxlTm9kZTozMw==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-08-05T22:37:42.356260+00:00",
#                     "url": "/media/uploads/sample_tfJGat5.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-06T10:38:09.884036+00:00",
#                     "id": "U2FtcGxlTm9kZTozNA==",
#                     "isOwner": true,
#                     "keywords": [
#                         "python",
#                         "test"
#                     ],
#                     "name": "test sample",
#                     "updated": "2021-08-06T10:38:09.884053+00:00",
#                     "url": "/media/uploads/sample_u9Eih58.json",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             }
#         ]
#     }
# }

# %%
sample_by_id = adc.sample("U2FtcGxlTm9kZTox")
print(sample_by_id)
# Out:
# This is your response:
# {
#     "sample": {
#         "created": "2021-07-22T14:24:24.872097+00:00",
#         "id": "U2FtcGxlTm9kZTox",
#         "isOwner": false,
#         "keywords": [
#             "Keyword 0",
#             "Keyword 1",
#             "Keyword 2",
#             "Keyword 3",
#             "Keyword 4"
#         ],
#         "name": "Test Sample 1",
#         "updated": "2021-07-22T14:24:24.880941+00:00",
#         "url": "/media/uploads/simplified_sample.json",
#         "user": {
#             "email": "mayodeanna@williamson.com",
#             "id": "VXNlck5vZGU6Mg==",
#             "username": "sherry38"
#         }
#     }
# }

# %%
investigations= adc.investigations()
print(investigations)
# Out:
# This is your response:
# {
#     "investigations": {
#         "edges": [
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.836075+00:00",
#                     "description": "Indeed it enter size. If table stuff bill dark happy majority. Cell north on north.",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MQ==",
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Investigation 0",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZTox",
#                             "name": "Test Sample 1",
#                             "url": "/media/uploads/simplified_sample.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-07-22T14:24:24.836084+00:00",
#                     "user": {
#                         "email": "mayodeanna@williamson.com",
#                         "id": "VXNlck5vZGU6Mg==",
#                         "username": "sherry38"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.847524+00:00",
#                     "description": "Benefit his it. Remain drop base its. Usually environmental ability team worker.\nFamily indicate research. Film behind art fish travel you without. Population drug machine tough president.",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mg==",
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Investigation 1",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Drop defense star hospital raise recently. Policy possible degree often.\nWell us game Democrat.\nDetermine security music deal ball. Notice traditional allow protect country care glass.",
#                         "id": "U3R1ZHlOb2RlOjI=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 1"
#                     },
#                     "updated": "2021-07-22T14:24:24.847533+00:00",
#                     "user": {
#                         "email": "carrillopatrick@hotmail.com",
#                         "id": "VXNlck5vZGU6Mw==",
#                         "username": "combsashlee"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.854446+00:00",
#                     "description": "Level power song parent its buy small. Society agreement though. Then whose build class debate significant.",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6Mw==",
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Investigation 2",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToz",
#                             "name": "Test Sample 3",
#                             "url": "/media/uploads/simplified_sample_UYlPLPB.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Threat collection management skill general. Security statement range.\nEdge security water choice determine save fire simply. Campaign drug pass subject. Yes expect campaign his end this.",
#                         "id": "U3R1ZHlOb2RlOjM=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 2"
#                     },
#                     "updated": "2021-07-22T14:24:24.854453+00:00",
#                     "user": {
#                         "email": "peggyspears@yahoo.com",
#                         "id": "VXNlck5vZGU6NA==",
#                         "username": "mmckay"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.859853+00:00",
#                     "description": "Catch ahead such something town wonder address. Pm thank that recognize. Window these against decade part player mission.",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6NA==",
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Investigation 3",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZTo0",
#                             "name": "Test Sample 4",
#                             "url": "/media/uploads/simplified_sample_qANM8An.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Wind purpose in product himself collection say. Language somebody fill future. Impact tree model.",
#                         "id": "U3R1ZHlOb2RlOjQ=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 3"
#                     },
#                     "updated": "2021-07-22T14:24:24.859859+00:00",
#                     "user": {
#                         "email": "peterscristina@hotmail.com",
#                         "id": "VXNlck5vZGU6NQ==",
#                         "username": "rfuller"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:24:24.864781+00:00",
#                     "description": "Maybe professor beyond than. Pay important home.\nWhen approach shoulder. Media allow state attorney. Physical product enter professional hot station dream.",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6NQ==",
#                     "isOwner": false,
#                     "keywords": [
#                         "Keyword 0",
#                         "Keyword 1",
#                         "Keyword 2",
#                         "Keyword 3",
#                         "Keyword 4"
#                     ],
#                     "name": "Test Investigation 4",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZTo1",
#                             "name": "Test Sample 5",
#                             "url": "/media/uploads/simplified_sample_FsuBL5A.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Plant window education inside test. Spring know figure certainly want development brother.\nCouple throw fish suddenly. Individual kitchen factor develop network institution.",
#                         "id": "U3R1ZHlOb2RlOjU=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 4"
#                     },
#                     "updated": "2021-07-22T14:24:24.864786+00:00",
#                     "user": {
#                         "email": "icabrera@gmail.com",
#                         "id": "VXNlck5vZGU6Ng==",
#                         "username": "kentsanchez"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:25:02.619215+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6Ng==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-07-22T14:25:02.619226+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T14:26:07.152748+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6Nw==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-07-22T14:26:07.152769+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-07-22T20:13:51.457692+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6OA==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-07-22T20:13:51.457712+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:02:44.644476+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6OQ==",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-08-05T18:02:44.644493+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:04:58.847089+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTA=",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-08-05T18:04:58.847103+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T18:15:59.723331+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTE=",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-08-05T18:15:59.723344+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T22:30:17.110651+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTI=",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-08-05T22:30:17.110659+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-05T22:36:20.423758+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTM=",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-08-05T22:36:20.423766+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-06T10:10:13.768887+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTQ=",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-08-06T10:10:13.768896+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-06T10:33:47.984544+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTU=",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-08-06T10:33:47.984602+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-06T10:36:48.432031+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTY=",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-08-06T10:36:48.432047+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             },
#             {
#                 "node": {
#                     "created": "2021-08-06T11:11:23.141161+00:00",
#                     "description": "Test Study Description",
#                     "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTc=",
#                     "isOwner": true,
#                     "keywords": [
#                         "test",
#                         "graphql",
#                         "demo",
#                         "argonne"
#                     ],
#                     "name": "Test Study Name",
#                     "samples": [
#                         {
#                             "id": "U2FtcGxlTm9kZToy",
#                             "name": "Test Sample 2",
#                             "url": "/media/uploads/simplified_sample_8JF3Ryx.json"
#                         }
#                     ],
#                     "study": {
#                         "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#                         "id": "U3R1ZHlOb2RlOjE=",
#                         "keywords": [
#                             "Keyword 0",
#                             "Keyword 1",
#                             "Keyword 2",
#                             "Keyword 3",
#                             "Keyword 4"
#                         ],
#                         "name": "Test Study 0"
#                     },
#                     "updated": "2021-08-06T11:11:23.141169+00:00",
#                     "user": {
#                         "email": "gonzalo.martinez@domandtom.com",
#                         "id": "VXNlck5vZGU6MQ==",
#                         "username": "gonzalo.martinez@domandtom.com"
#                     }
#                 }
#             }
#         ]
#     }
# }

# %%
investigations_by_id= adc.investigation("SW52ZXN0aWdhdGlvbk5vZGU6MQ==")
print(investigations_by_id)
# Out:
# This is your response:
# {
#     "investigation": {
#         "created": "2021-07-22T14:24:24.836075+00:00",
#         "description": "Indeed it enter size. If table stuff bill dark happy majority. Cell north on north.",
#         "id": "SW52ZXN0aWdhdGlvbk5vZGU6MQ==",
#         "isOwner": false,
#         "keywords": [
#             "Keyword 0",
#             "Keyword 1",
#             "Keyword 2",
#             "Keyword 3",
#             "Keyword 4"
#         ],
#         "name": "Test Investigation 0",
#         "samples": [
#             {
#                 "id": "U2FtcGxlTm9kZTox",
#                 "name": "Test Sample 1",
#                 "url": "/media/uploads/simplified_sample.json"
#             }
#         ],
#         "study": {
#             "description": "Offer concern notice state me knowledge. Drug same man door skin. Region drive clearly American crime argue who.\nAnd must idea building carry.\nWestern teacher hard this assume father professor.",
#             "id": "U3R1ZHlOb2RlOjE=",
#             "keywords": [
#                 "Keyword 0",
#                 "Keyword 1",
#                 "Keyword 2",
#                 "Keyword 3",
#                 "Keyword 4"
#             ],
#             "name": "Test Study 0"
#         },
#         "updated": "2021-07-22T14:24:24.836084+00:00",
#         "user": {
#             "email": "mayodeanna@williamson.com",
#             "id": "VXNlck5vZGU6Mg==",
#             "username": "sherry38"
#         }
#     }
# }

# %%
investigation_sample = """{
    "name": "Test Study Name",
    "description": "Test Study Description",
    "keywords": ["test", "graphql", "demo", "argonne"],
    "sampleGlobalIds" : ["VXNlck5vZGU6Mg=="],
    "studyGlobalId": "U3R1ZHlOb2RlOjE="
}"""
create_investigation = adc.createInvestigation(investigation_sample)
print(create_investigation)
# Out:
# This is your response:
# {
#     "createInvestigation": {
#         "investigation": {
#             "description": "Test Study Description",
#             "id": "SW52ZXN0aWdhdGlvbk5vZGU6MTg=",
#             "isOwner": true,
#             "keywords": [
#                 "test",
#                 "graphql",
#                 "demo",
#                 "argonne"
#             ],
#             "name": "Test Study Name",
#             "samples": [
#                 {
#                     "id": "U2FtcGxlTm9kZToy"
#                 }
#             ],
#             "study": {
#                 "id": "U3R1ZHlOb2RlOjE=",
#                 "name": "Test Study 0"
#             },
#             "user": {
#                 "id": "VXNlck5vZGU6MQ==",
#                 "username": "gonzalo.martinez@domandtom.com"
#             }
#         }
#     }
# }
